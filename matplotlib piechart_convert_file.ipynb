# %%
import matplotlib.pyplot as py
# %matplotlib inline

exp_vals = [1200,200,300,600,100,]
exp_labels = ["Rent", "Travel", "Food","unknown ", "shopping"]
plt.axis("equal")
plt.pie(exp_vals,labels= exp_labels, autopct="%0.2f%%", radius = 1.5,shadow = True, explode=[0,0,0,0.2,0], startangle=45)
plt.show()
plt.savefig("piechart.jpg", bbox_inches ="tight",pad_inches =1,transparent = True)
